# %% [markdown]
# # Small dataset training
#
# 利用datagenerator來增廣數據集做訓練
#
# ### Step1. 設定資料集
#
#
# 需要把當前的資料另外建立出一個資料夾結構如下
# 目的是為了使用keras內建的檔案處理data generator的load_from_di來利用資料夾做分類
#
# ```
# root_floder/
#    ├────/TRAIN
#    |      ├──/DOG
#    |      └──/CAT
#    ├────/TEST
#    |      ├──/DOG
#    |      └──/CAT
#    └────/VAL
#           ├──/DOG
#           └──/CAT
# ```

# %%
import os

ROOT_DIR = os.getcwd()
DATA_PATH = os.path.join(ROOT_DIR, "dogs-vs-cats")
SOURCE_DATA_DIR = os.path.join(DATA_PATH, "train")

print('length of train data %d' %(len(os.listdir(SOURCE_DATA_DIR))))
# Out:
# length of train data 25000

# %%
BASE_DIR = os.path.join(DATA_PATH, "VGG_Practice")
if not os.path.exists(BASE_DIR):
    os.mkdir(BASE_DIR)
    
TRAIN_DIR = os.path.join(BASE_DIR, "TRAIN")
if not os.path.exists(TRAIN_DIR):
    os.mkdir(TRAIN_DIR)
    
TEST_DIR = os.path.join(BASE_DIR, "TEST")
if not os.path.exists(TEST_DIR):
    os.mkdir(TEST_DIR)

VAL_DIR = os.path.join(BASE_DIR, "Validation")
if not os.path.exists(VAL_DIR):
    os.mkdir(VAL_DIR)
    
DOG_TRAIN = os.path.join(TRAIN_DIR, "DOG")
if not os.path.exists(DOG_TRAIN):
    os.mkdir(DOG_TRAIN)

CAT_TRAIN = os.path.join(TRAIN_DIR, "CAT")
if not os.path.exists(CAT_TRAIN):
    os.mkdir(CAT_TRAIN)
    
DOG_TEST = os.path.join(TEST_DIR, "DOG")
if not os.path.exists(DOG_TEST):
    os.mkdir(DOG_TEST)
    
CAT_TEST = os.path.join(TEST_DIR, "CAT")
if not os.path.exists(CAT_TEST):
    os.mkdir(CAT_TEST)

    
DOG_VAL = os.path.join(VAL_DIR, "DOG")
if not os.path.exists(DOG_VAL):
    os.mkdir(DOG_VAL)

CAT_VAL = os.path.join(VAL_DIR, "CAT")
if not os.path.exists(CAT_VAL):
    os.mkdir(CAT_VAL)

# %%
import shutil

for frame in ['cat.{}.jpg'.format(i) for i in range(0,2000)]:
    source = os.path.join(SOURCE_DATA_DIR,frame)
    target = os.path.join(CAT_TRAIN,frame)
    if not os.path.exists(target):
        shutil.copyfile(source,target)

for frame in ['dog.{}.jpg'.format(i) for i in range(0,2000)]:
    source = os.path.join(SOURCE_DATA_DIR,frame)
    target = os.path.join(DOG_TRAIN,frame)
    if not os.path.exists(target):
        shutil.copyfile(source,target)
        
for frame in ['cat.{}.jpg'.format(i) for i in range(10000,11000)]:
    source = os.path.join(SOURCE_DATA_DIR,frame)
    target = os.path.join(CAT_TEST,frame)
    if not os.path.exists(target):
        shutil.copyfile(source,target)
        
for frame in ['dog.{}.jpg'.format(i) for i in range(10000,11000)]:
    source = os.path.join(SOURCE_DATA_DIR,frame)
    target = os.path.join(DOG_TEST,frame)
    if not os.path.exists(target):
        shutil.copyfile(source,target)

for frame in ['cat.{}.jpg'.format(i) for i in range(2001,3001)]:
    source = os.path.join(SOURCE_DATA_DIR,frame)
    target = os.path.join(CAT_VAL,frame)
    if not os.path.exists(target):
        shutil.copyfile(source,target)

for frame in ['dog.{}.jpg'.format(i) for i in range(2001,3001)]:
    source = os.path.join(SOURCE_DATA_DIR,frame)
    target = os.path.join(DOG_VAL,frame)
    if not os.path.exists(target):
        shutil.copyfile(source,target)

# %% [markdown]
# ### Step2. 資料預處理
#
# 由於圖檔大小不一
# 需要先將其設定到固定大小並且歸一化處理

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

batch_size = 40

Train_gen = datagen.flow_from_directory(
                TRAIN_DIR,
                target_size=(150,150),
                batch_size=batch_size,
                class_mode='binary')

Test_gen = datagen.flow_from_directory(
                TEST_DIR,
                target_size=(150,150),
                batch_size=batch_size,
                class_mode='binary')

Val_gen = datagen.flow_from_directory(
                VAL_DIR,
                target_size=(150,150),
                batch_size=batch_size,
                class_mode='binary')
# Out:
# Found 4000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ### Step3. 模型設計與訓練
#
# 簡單設計一個CNN

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPool2D, Dropout

model = Sequential()

model.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu',input_shape=(150,150,3)))
model.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2),padding='same'))
model.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2),padding='same'))
model.add(Conv2D(filters=50,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(Conv2D(filters=50,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2),padding='same'))
model.add(Flatten())
model.add(Dense(20,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 150, 150, 30)      840
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 150, 150, 30)      8130
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 75, 75, 30)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 75, 75, 30)        8130
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 75, 75, 30)        8130
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 38, 38, 30)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 38, 38, 50)        13550
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 38, 38, 50)        22550
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 19, 19, 50)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18050)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                361020
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 422,371
# Trainable params: 422,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

train_history= model.fit_generator(Train_gen,
                                   steps_per_epoch=4000/batch_size,
                                   epochs=30,
                                   validation_data=Val_gen,
                                   validation_steps=2000/batch_size,
                                   verbose=1)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 14s 141ms/step - loss: 0.6737 - acc: 0.5617 - val_loss: 0.6983 - val_acc: 0.5630
# Epoch 2/30
# 100/100 [==============================] - 13s 128ms/step - loss: 0.6474 - acc: 0.5950 - val_loss: 0.6231 - val_acc: 0.6205
# Epoch 3/30
# 100/100 [==============================] - 13s 128ms/step - loss: 0.6020 - acc: 0.6635 - val_loss: 0.5950 - val_acc: 0.7000
# Epoch 4/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.5557 - acc: 0.7138 - val_loss: 0.5903 - val_acc: 0.6870
# Epoch 5/30
# 100/100 [==============================] - 13s 129ms/step - loss: 0.5266 - acc: 0.7383 - val_loss: 0.5525 - val_acc: 0.7350
# Epoch 6/30
# 100/100 [==============================] - 13s 129ms/step - loss: 0.4848 - acc: 0.7618 - val_loss: 0.5570 - val_acc: 0.7325
# Epoch 7/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.4359 - acc: 0.7910 - val_loss: 0.5438 - val_acc: 0.7390
# Epoch 8/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.3884 - acc: 0.8135 - val_loss: 0.5577 - val_acc: 0.7395
# Epoch 9/30
# 100/100 [==============================] - 13s 129ms/step - loss: 0.3323 - acc: 0.8505 - val_loss: 0.6574 - val_acc: 0.7340
# Epoch 10/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.2544 - acc: 0.8888 - val_loss: 0.6819 - val_acc: 0.7315
# Epoch 11/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.1875 - acc: 0.9193 - val_loss: 0.7721 - val_acc: 0.7310
# Epoch 12/30
# 100/100 [==============================] - 13s 132ms/step - loss: 0.1268 - acc: 0.9520 - val_loss: 1.0768 - val_acc: 0.7255
# Epoch 13/30
# 100/100 [==============================] - 13s 132ms/step - loss: 0.1080 - acc: 0.9568 - val_loss: 1.2595 - val_acc: 0.7290
# Epoch 14/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0649 - acc: 0.9778 - val_loss: 1.3159 - val_acc: 0.7355
# Epoch 15/30
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0432 - acc: 0.9850 - val_loss: 1.4802 - val_acc: 0.7340
# Epoch 16/30
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0783 - acc: 0.9748 - val_loss: 1.5220 - val_acc: 0.7290
# Epoch 17/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0702 - acc: 0.9783 - val_loss: 1.3749 - val_acc: 0.7190
# Epoch 18/30
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0388 - acc: 0.9885 - val_loss: 1.2053 - val_acc: 0.7365
# Epoch 19/30
# 100/100 [==============================] - 13s 132ms/step - loss: 0.0315 - acc: 0.9908 - val_loss: 1.5653 - val_acc: 0.7220
# Epoch 20/30
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0303 - acc: 0.9898 - val_loss: 1.5746 - val_acc: 0.7250
# Epoch 21/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0164 - acc: 0.9960 - val_loss: 1.7726 - val_acc: 0.7220
# Epoch 22/30
# 100/100 [==============================] - 13s 133ms/step - loss: 0.0318 - acc: 0.9905 - val_loss: 1.8805 - val_acc: 0.7275
# Epoch 23/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0394 - acc: 0.9868 - val_loss: 1.7950 - val_acc: 0.7160
# Epoch 24/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0265 - acc: 0.9933 - val_loss: 1.6723 - val_acc: 0.7220
# Epoch 25/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0088 - acc: 0.9978 - val_loss: 1.7996 - val_acc: 0.7415
# Epoch 26/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0035 - acc: 0.9998 - val_loss: 1.9506 - val_acc: 0.7325
# Epoch 27/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0030 - acc: 0.9998 - val_loss: 2.0036 - val_acc: 0.7335
# Epoch 28/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0029 - acc: 0.9998 - val_loss: 2.0539 - val_acc: 0.7320
# Epoch 29/30
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0029 - acc: 0.9998 - val_loss: 2.0846 - val_acc: 0.7305
# Epoch 30/30
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 2.1834 - val_acc: 0.7255

# %%
import matplotlib.pyplot as plt

def plot_train_result(train_history,train,val):
    plt.figure()
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[val])
    plt.legend(['train','validation'])
    plt.title(train+'_history')
    plt.xlabel('Epoch')
    plt.ylabel(train,fontsize=20)
    plt.show()
    
plot_train_result(train_history,'acc','val_acc')

# %%
plot_train_result(train_history,'loss','val_loss')

# %% [markdown]
# 在小數據集上訓練，最後結果在validation set上面遇到overfitting是不意外的結果

# %%
scores = model.evaluate_generator(Test_gen,Test_gen.samples/batch_size)
print('test data accuracy: %.2f' %(scores[1]*100))
# Out:
# test data accuracy: 73.35

# %% [markdown]
# ### Step4. 產生更多資料
#
# 在上面的結果是來自於我們的訓練資料集，共兩千張貓與兩千張狗的訓練成果
# 接下來我們利用ImageDataGenerator來產生更多的訓練圖集
# [ImageDataGenerator](https://keras.io/preprocessing/image/)

# %%
datagen2=ImageDataGenerator(rotation_range=30,
                            rescale=1./255,
                            shear_range=0.2,
                            width_shift_range=0.2,
                            height_shift_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest'
                           )

# %% [markdown]
# 利用此datagenerator來畫出幾張圖像看看
# 可以得到藉由 平移/縮放/旋轉...等等，獲得的圖像

# %%
from keras.preprocessing import image

img = os.path.join(SOURCE_DATA_DIR,'dog.10.jpg')

image_ent = image.load_img(img,target_size=(200,200)) 

image_ent = image.img_to_array(image_ent)

image_ent = image_ent.reshape((1,)+image_ent.shape)
i = 0
for images in datagen2.flow(image_ent,batch_size=1):
    
    images = image.array_to_img(images[0])    
    plt.figure(i)
    plt.imshow(images)

    i+=1
    if i == 4:
        break

# %% [markdown]
# 建立另一組Data generator

# %%
Train_gen2 = datagen2.flow_from_directory(
                TRAIN_DIR,
                target_size=(150,150),
                batch_size=batch_size,
                class_mode='binary')

Test_gen2 = datagen2.flow_from_directory(
                TEST_DIR,
                target_size=(150,150),
                batch_size=batch_size,
                class_mode='binary')

Val_gen2 = datagen2.flow_from_directory(
                VAL_DIR,
                target_size=(150,150),
                batch_size=batch_size,
                class_mode='binary')
# Out:
# Found 4000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ### Step5. 建立另外一組模型來看結果
# 模型的架構跟上一組是一樣的
# 利用一樣的架構一樣的訓練做基準來比較兩者的結果

# %%
model2 = Sequential()

model2.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu',input_shape=(150,150,3)))
model2.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model2.add(MaxPool2D(pool_size=(2,2),strides=(2,2),padding='same'))
model2.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model2.add(Conv2D(filters=30,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model2.add(MaxPool2D(pool_size=(2,2),strides=(2,2),padding='same'))
model2.add(Conv2D(filters=50,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model2.add(Conv2D(filters=50,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model2.add(MaxPool2D(pool_size=(2,2),strides=(2,2),padding='same'))
model2.add(Flatten())
model2.add(Dense(20,activation='relu'))
model2.add(Dense(1,activation='sigmoid'))

model2.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 150, 150, 30)      840
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 150, 150, 30)      8130
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 75, 75, 30)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 75, 75, 30)        8130
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 75, 75, 30)        8130
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 38, 38, 30)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 38, 38, 50)        13550
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 38, 38, 50)        22550
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 19, 19, 50)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18050)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                361020
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 422,371
# Trainable params: 422,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_history2= model2.fit_generator(Train_gen2,
                                     steps_per_epoch=4000/batch_size,
                                     epochs=30,
                                     validation_data=Val_gen2,
                                     validation_steps=2000/batch_size,
                                     verbose=1)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 37s 365ms/step - loss: 0.6940 - acc: 0.5222 - val_loss: 0.6930 - val_acc: 0.5055
# Epoch 2/30
# 100/100 [==============================] - 33s 333ms/step - loss: 0.6888 - acc: 0.5325 - val_loss: 0.6844 - val_acc: 0.5585
# Epoch 3/30
# 100/100 [==============================] - 33s 332ms/step - loss: 0.6771 - acc: 0.5712 - val_loss: 0.6829 - val_acc: 0.5815
# Epoch 4/30
# 100/100 [==============================] - 33s 330ms/step - loss: 0.6854 - acc: 0.5447 - val_loss: 0.6798 - val_acc: 0.5800
# Epoch 5/30
# 100/100 [==============================] - 33s 329ms/step - loss: 0.6797 - acc: 0.5672 - val_loss: 0.6806 - val_acc: 0.5610
# Epoch 6/30
# 100/100 [==============================] - 33s 328ms/step - loss: 0.6791 - acc: 0.5645 - val_loss: 0.6680 - val_acc: 0.5855
# Epoch 7/30
# 100/100 [==============================] - 33s 332ms/step - loss: 0.6731 - acc: 0.5852 - val_loss: 0.6658 - val_acc: 0.6065
# Epoch 8/30
# 100/100 [==============================] - 33s 327ms/step - loss: 0.6544 - acc: 0.6143 - val_loss: 0.6453 - val_acc: 0.6330
# Epoch 9/30
# 100/100 [==============================] - 33s 327ms/step - loss: 0.6450 - acc: 0.6240 - val_loss: 0.6305 - val_acc: 0.6550
# Epoch 10/30
# 100/100 [==============================] - 33s 326ms/step - loss: 0.6282 - acc: 0.6493 - val_loss: 0.6528 - val_acc: 0.6130
# Epoch 11/30
# 100/100 [==============================] - 33s 327ms/step - loss: 0.6234 - acc: 0.6438 - val_loss: 0.6324 - val_acc: 0.6315
# Epoch 12/30
# 100/100 [==============================] - 33s 326ms/step - loss: 0.6161 - acc: 0.6710 - val_loss: 0.6697 - val_acc: 0.5940
# Epoch 13/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5982 - acc: 0.6888 - val_loss: 0.6218 - val_acc: 0.6625
# Epoch 14/30
# 100/100 [==============================] - 33s 325ms/step - loss: 0.5849 - acc: 0.6895 - val_loss: 0.5924 - val_acc: 0.6845
# Epoch 15/30
# 100/100 [==============================] - 33s 326ms/step - loss: 0.5823 - acc: 0.7050 - val_loss: 0.6344 - val_acc: 0.6345
# Epoch 16/30
# 100/100 [==============================] - 32s 323ms/step - loss: 0.5720 - acc: 0.7082 - val_loss: 0.5684 - val_acc: 0.7090
# Epoch 17/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5580 - acc: 0.7228 - val_loss: 0.5756 - val_acc: 0.7060
# Epoch 18/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5556 - acc: 0.7150 - val_loss: 0.5677 - val_acc: 0.7090
# Epoch 19/30
# 100/100 [==============================] - 33s 326ms/step - loss: 0.5559 - acc: 0.7170 - val_loss: 0.5428 - val_acc: 0.7350
# Epoch 20/30
# 100/100 [==============================] - 33s 325ms/step - loss: 0.5377 - acc: 0.7267 - val_loss: 0.5526 - val_acc: 0.7210
# Epoch 21/30
# 100/100 [==============================] - 32s 325ms/step - loss: 0.5323 - acc: 0.7345 - val_loss: 0.5304 - val_acc: 0.7375
# Epoch 22/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5199 - acc: 0.7402 - val_loss: 0.5546 - val_acc: 0.7120
# Epoch 23/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5157 - acc: 0.7430 - val_loss: 0.5492 - val_acc: 0.7250
# Epoch 24/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5142 - acc: 0.7543 - val_loss: 0.5345 - val_acc: 0.7345
# Epoch 25/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5251 - acc: 0.7325 - val_loss: 0.5371 - val_acc: 0.7325
# Epoch 26/30
# 100/100 [==============================] - 33s 328ms/step - loss: 0.5016 - acc: 0.7595 - val_loss: 0.5503 - val_acc: 0.7210
# Epoch 27/30
# 100/100 [==============================] - 32s 325ms/step - loss: 0.5041 - acc: 0.7585 - val_loss: 0.5462 - val_acc: 0.7395
# Epoch 28/30
# 100/100 [==============================] - 32s 324ms/step - loss: 0.5064 - acc: 0.7540 - val_loss: 0.5204 - val_acc: 0.7440
# Epoch 29/30
# 100/100 [==============================] - 33s 327ms/step - loss: 0.4729 - acc: 0.7720 - val_loss: 0.5396 - val_acc: 0.7295
# Epoch 30/30
# 100/100 [==============================] - 33s 326ms/step - loss: 0.4786 - acc: 0.7695 - val_loss: 0.5175 - val_acc: 0.7455

# %%
plot_train_result(train_history2,'acc','val_acc')

# %%
plot_train_result(train_history2,'loss','val_loss')

# %% [markdown]
# 可以看到validation的loss有效的下降

# %%
model2.save('dog-cat_little.h5')

# %% [markdown]
# 儲存模型另作他用
